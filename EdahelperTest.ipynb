# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\OneDrive\\Documents'

# %%
import sys, os
sys.path.append(os.path.abspath('.'))  # make sure edahelper is visible

import edahelper
from edahelper import show

# %%
# %reload_ext autoreload
# %autoreload 2
import importlib, edahelper
importlib.reload(edahelper)
# Out:
# <module 'edahelper' from 'C:\\Users\\DELL\\OneDrive\\Documents\\edahelp_task\\edahelper\\__init__.py'>

# %%
import edahelper as eda

# %%
eda.show()
# Out:
# ──────────────────────────────────────────── 📘 EDA Helper Cheat Sheet ────────────────────────────────────────────
# Simplify your exploratory data analysis with Python & pandas
# ╭───────────────── Data Loading ──────────────────╮
# │ ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │
# │ ┃ Command    ┃ Example Syntax                 ┃ │
# │ ┡━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩ │
# │ │ Read CSV   │ pd.read_csv('file.csv')        │ │
# │ │ Read Excel │ pd.read_excel('file.xlsx')     │ │
# │ │ Read JSON  │ pd.read_json('file.json')      │ │
# │ │ Read SQL   │ pd.read_sql(query, connection) │ │
# │ └────────────┴────────────────────────────────┘ │
# ╰─────────────────────────────────────────────────╯
# ╭──────── Data Overview ────────╮
# │ ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━┓ │
# │ ┃ Command  ┃ Example Syntax ┃ │
# │ ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━┩ │
# │ │ Head     │ df.head()      │ │
# │ │ Tail     │ df.tail()      │ │
# │ │ Info     │ df.info()      │ │
# ...

# %%
eda.core.show()
# Out:
# ✨ EDA Helper — Interactive Cheat Sheet ✨
# ╭───────────────────────────────────────────────── Data Loading ──────────────────────────────────────────────────╮
# │ Read CSV — Loads a CSV file into a pandas DataFrame.                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# │  df = pd.read_csv('file.csv')                                                                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# │ Read Excel — Reads Excel files with optional sheet selection.                                                   │
# ...
