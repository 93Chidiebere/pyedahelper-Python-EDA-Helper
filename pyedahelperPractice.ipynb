# %%
# pip install pyedahelper

# %%
import pandas as pd
import edahelper as eda
from edahelper import inspect

# %%
eda.show()
# Out:
# ──────────────────────────────────────────── 📘 EDA Helper Cheat Sheet ────────────────────────────────────────────
# Simplify your exploratory data analysis with Python & pandas
# ╭───────────────── Data Loading ──────────────────╮
# │ ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │
# │ ┃ Command    ┃ Example Syntax                 ┃ │
# │ ┡━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩ │
# │ │ Read CSV   │ pd.read_csv('file.csv')        │ │
# │ │ Read Excel │ pd.read_excel('file.xlsx')     │ │
# │ │ Read JSON  │ pd.read_json('file.json')      │ │
# │ │ Read SQL   │ pd.read_sql(query, connection) │ │
# │ └────────────┴────────────────────────────────┘ │
# ╰─────────────────────────────────────────────────╯
# ╭──────── Data Overview ────────╮
# │ ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━┓ │
# │ ┃ Command  ┃ Example Syntax ┃ │
# │ ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━┩ │
# │ │ Head     │ df.head()      │ │
# │ │ Tail     │ df.tail()      │ │
# │ │ Info     │ df.info()      │ │
# │ │ Describe │ df.describe()  │ │
# │ │ Shape    │ df.shape       │ │
# │ │ Columns  │ df.columns     │ │
# │ └──────────┴────────────────┘ │
# ╰───────────────────────────────╯
# ╭──────────────────── Data Cleaning ─────────────────────╮
# │ ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │
# │ ┃ Command         ┃ Example Syntax                   ┃ │
# │ ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩ │
# │ │ Drop NaN        │ df.dropna()                      │ │
# │ │ Fill NaN        │ df.fillna(value)                 │ │
# │ │ Rename Columns  │ df.rename(columns={'old':'new'}) │ │
# │ │ Replace Values  │ df.replace({'old':'new'})        │ │
# │ │ Drop Duplicates │ df.drop_duplicates()             │ │
# │ └─────────────────┴──────────────────────────────────┘ │
# ╰────────────────────────────────────────────────────────╯
# ╭─────────────────────────── Feature Engineering ───────────────────────────╮
# │ ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │
# │ ┃ Command             ┃ Example Syntax                                  ┃ │
# │ ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩ │
# │ │ Create New Column   │ df['new'] = df['A'] + df['B']                   │ │
# │ │ Map Values          │ df['Gender'] = df['Gender'].map({'M':1, 'F':0}) │ │
# │ │ Binning             │ pd.cut(df['Age'], bins=[0,18,35,60,100])        │ │
# │ │ Datetime Conversion │ pd.to_datetime(df['date'])                      │ │
# │ └─────────────────────┴─────────────────────────────────────────────────┘ │
# ╰───────────────────────────────────────────────────────────────────────────╯
# ╭────────────────── Visualization ───────────────────╮
# │ ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │
# │ ┃ Command             ┃ Example Syntax           ┃ │
# │ ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩ │
# │ │ Histogram           │ df['col'].hist()         │ │
# │ │ Boxplot             │ df.boxplot(column='col') │ │
# │ │ Scatter Plot        │ df.plot.scatter('x','y') │ │
# │ │ Correlation Heatmap │ sns.heatmap(df.corr())   │ │
# │ └─────────────────────┴──────────────────────────┘ │
# ╰────────────────────────────────────────────────────╯
# ╭──────────────────────── Summarization ────────────────────────╮
# │ ┏━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │
# │ ┃ Command       ┃ Example Syntax                            ┃ │
# │ ┡━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩ │
# │ │ Value Counts  │ df['col'].value_counts()                  │ │
# │ │ Unique Values │ df['col'].unique()                        │ │
# │ │ Group By      │ df.groupby('col').mean()                  │ │
# │ │ Pivot Table   │ pd.pivot_table(df, index='A', values='B') │ │
# │ └───────────────┴───────────────────────────────────────────┘ │
# ╰───────────────────────────────────────────────────────────────╯
# ───────────────────────── 💡 Tip: Use edahelper.show() anytime you need a quick reminder! ─────────────────────────

# %%
df = pd.read_csv('fraud.csv')

# %%
eda.next_step('read_csv')
# Out:
# ✅ Dataset loaded! Try viewing the first few rows:
# 👉 `df.head()`

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud
# 0  M1979787155             0.0             NaN      0.0
# 1  M2044282225             0.0             NaN      0.0
# 2   C553264065             0.0             NaN      1.0
# 3    C38997010         21182.0             NaN      1.0
# 4  M1230701703             0.0             NaN      0.0

# %%
eda.next_step('head')
# Out:
# Next step: `columns` → See shape (rows, columns) using `df.shape`

# %%
df.shape
# Out:
# (541, 9)

# %%
eda.next_step('shape')
# Out:
# Next step: `info` → Summarize numeric data with `df.describe()`

# %%
inspect(df, target='isFraud')
# Out:
# {'dataset_shape': (541, 10),
#  'missing_values': {'by_column': {'type': {'missing_count': 3,
#     'missing_pct': 0.0055,
#     'row_indices_sample': [496, 497, 498],
#     'severity': 'low',
#     'recommended_action': 'monitor'},
#    'newbalanceDest': {'missing_count': 9,
#     'missing_pct': 0.0166,
#     'row_indices_sample': [0, 1, 2, 3, 4, 5, 6, 7, 8],
#     'severity': 'low',
#     'recommended_action': 'monitor'},
#    'isFraud': {'missing_count': 3,
#     'missing_pct': 0.0055,
#     'row_indices_sample': [481, 482, 483],
#     'severity': 'low',
#     'recommended_action': 'monitor'}},
#   'cell_locations_sample': [(496, 'type'),
#    (497, 'type'),
#    (498, 'type'),
#    (0, 'newbalanceDest'),
#    (1, 'newbalanceDest'),
#    (2, 'newbalanceDest'),
#    (3, 'newbalanceDest'),
#    (4, 'newbalanceDest'),
#    (5, 'newbalanceDest'),
#    (6, 'newbalanceDest'),
#    (7, 'newbalanceDest'),
#    (8, 'newbalanceDest'),
#    (481, 'isFraud'),
#    (482, 'isFraud'),
#    (483, 'isFraud')]},
#  'duplicates': {'duplicate_count': 3,
#   'duplicate_pct': 0.0055,
#   'row_indices_sample': [538, 539, 540],
#   'recommended_action': 'deduplicate_rows'},
#  'constant_columns': {'constant': [],
#   'low_variance': ['isFraud'],
#   'recommended_action': 'drop_constant_columns'},
#  'dtype_issues': {},
#  'outliers': {'amount': {'outlier_count': 40,
#    'outlier_pct': 0.0739,
#    'severity': 'moderate',
#    'recommended_action': 'review_distribution'},
#   'oldbalanceOrg': {'outlier_count': 113,
#    'outlier_pct': 0.2089,
#    'severity': 'high',
#    'recommended_action': 'review_distribution'},
#   'newbalanceOrig': {'outlier_count': 116,
#    'outlier_pct': 0.2144,
#    'severity': 'high',
#    'recommended_action': 'review_distribution'},
#   'oldbalanceDest': {'outlier_count': 74,
#    'outlier_pct': 0.1368,
#    'severity': 'high',
#    'recommended_action': 'review_distribution'},
#   'newbalanceDest': {'outlier_count': 84,
#    'outlier_pct': 0.1553,
#    'severity': 'high',
#    'recommended_action': 'review_distribution'}},
#  'cardinality': {'nameOrig': {'unique_ratio': 0.9889,
#    'risk': 'high_cardinality_or_id_like',
#    'recommended_action': 'drop_or_target_encode'}},
#  'key_integrity': {'index': {'uniqueness_ratio': 1.0,
#    'possible_primary_key': True,
#    'recommended_action': 'exclude_from_features'},
#   'amount': {'uniqueness_ratio': 0.9852,
#    'possible_primary_key': True,
#    'recommended_action': 'exclude_from_features'},
#   'nameOrig': {'uniqueness_ratio': 0.9889,
#    'possible_primary_key': True,
#    'recommended_action': 'exclude_from_features'}},
#  'target_leakage': {},
#  'temporal_checks': None,
#  'warnings': ['Missing values detected.', 'Duplicate rows detected.']}

# %%
report = inspect(df, target='isFraud')
eda.summary(report)
# Out:
# EDA SUMMARY
# ───────────
# Dataset shape: 541 rows × 10 columns
#
# DATA QUALITY
# • Missing values detected
# • Duplicate rows: 3
# • Low-variance columns: isFraud
#
# FEATURE RISKS
# • Outliers detected in 5 numeric columns
#   - amount (7.4% of rows)
#   - oldbalanceOrg (20.9% of rows)
#   - newbalanceOrig (21.4% of rows)
#   - oldbalanceDest (13.7% of rows)
#   - newbalanceDest (15.5% of rows)
#
# ENCODING & KEYS
# • High-cardinality columns:
#   - nameOrig (likely ID)
# • Possible primary keys:
#   - index
#   - amount
#   - nameOrig
#
# ACTIONABLE NEXT STEPS
# 1. Exclude ID-like columns from modeling
# 2. Review skewed numeric features before modeling
